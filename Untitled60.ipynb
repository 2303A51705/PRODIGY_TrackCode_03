# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51705/PRODIGY_TrackCode_03/blob/main/Untitled60.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.decomposition import PCA

# %%
zip_path = "/content/cats_dogs_sample.zip"  # adjust if needed
extract_dir = "/content/cats_dogs_sample"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# %%
def load_images(folder, img_size=(64, 64)):
    X, y = [], []
    for label, cls in enumerate(["cat", "dog"]):
        cls_folder = os.path.join(folder, cls)
        for file in os.listdir(cls_folder):
            if file.endswith(".jpg"):
                path = os.path.join(cls_folder, file)
                img = Image.open(path).convert("L").resize(img_size)
                X.append(np.array(img).flatten())
                y.append(label)
    return np.array(X), np.array(y)

data_path = extract_dir
X, y = load_images(data_path)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
svm = SVC(kernel='rbf', C=1, gamma='scale', probability=True)
svm.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1, probability=True)

# %%
y_pred = svm.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=["cat", "dog"]))
# Out:
# Accuracy: 0.3333333333333333
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          cat       0.00      0.00      0.00         2
#          dog       0.33      1.00      0.50         1
#
#     accuracy                           0.33         3
#    macro avg       0.17      0.50      0.25         3
# weighted avg       0.11      0.33      0.17         3
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["cat", "dog"], yticklabels=["cat", "dog"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
pca = PCA(n_components=2)
X_all_scaled = np.vstack((X_train_scaled, X_test_scaled))
X_reduced = pca.fit_transform(X_all_scaled)
y_all = np.concatenate((y_train, y_test))
pred_all = svm.predict(X_all_scaled)

plt.figure(figsize=(8, 5))
sns.scatterplot(x=X_reduced[:, 0], y=X_reduced[:, 1], hue=pred_all, palette=["green", "orange"], style=y_all, s=100)
plt.title("PCA Feature Space: Predicted Classes (shapes show true labels)")
plt.legend(title="Predicted Class")
plt.show()

# %%
def show_images(X_scaled, y_true, y_pred, title):
    plt.figure(figsize=(10, 4))
    for i in range(min(6, len(X_scaled))):
        img = scaler.inverse_transform([X_scaled[i]])[0].reshape(64, 64)
        plt.subplot(2, 3, i + 1)
        plt.imshow(img, cmap='gray')
        true_lbl = "Dog" if y_true[i] else "Cat"
        pred_lbl = "Dog" if y_pred[i] else "Cat"
        color = "green" if y_true[i] == y_pred[i] else "red"
        plt.title(f"True: {true_lbl}\nPred: {pred_lbl}", color=color)
        plt.axis('off')
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

show_images(X_test_scaled, y_test, y_pred, "Sample Classified Test Images")
